# %%
import base64
import requests
import re
import json
import pandas as pd
import os

# %%
api_key = "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"
# Path to your image
#image_path = '/home/ec2-user/SageMaker/genebanks/data/2_images/Germplasm collection-Colombia-1990/page_29.png'
#image_path = '/home/ec2-user/SageMaker/genebanks/data/2_images/Ecogeographic survey of the target species-Costa Rica-2004'
prompt = """Actúa como observador de colectas que encuentra y extrae la información solicitada de una imagen de un informe de colecta.
Necesito que extraigas TODA la información específica donde encuentres altitud, latitud y longitud y la estructures en formato JSON que contenga todas las accesiones diferentes
relacionadas en esa colección y asignar a cada una la información correspondiente de: colector, número de accesión, país, departamento, estatus, especie, nombre local, municipio, fuente, fecha, lugar, altitud, longitud, latitud. 
Puede haber más información o menos información que la mencionada. El objetivo que no debes dejar pasar es el identificador de la semilla, altitud, longitud y latitud en TODO.

Este es un ejemplo de como deberia resultar la data de una accesión:

    "colectores": "DEBOUCK DG LOPEZ L ANGULO N & TORO O",
    "numero_accesión": 2928,
    "pais": "CLB",
    "departamento": "HUILA",
    "municipio": "SANTA MARIA",
    "especie": "P.lunatus",
    "lugar": "7 Km W Puerto El Socorro, Las Delicias",
    "altitud": 1030,
    "longitud": "75.34W",
    "latitud": "02.57N"

Aquí está la imagen que necesito que procese"""

# %%
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')
  
def stringToJson(text):
    json_match = re.search(r'```json\n(.*\n)```', text, re.DOTALL)
    if json_match:
        json_str = json_match.group(1).strip()
        try:
            # Carga el JSON desde la cadena
            json_data = json.loads(json_str)
            return json_data
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            return None
    else:
        print("No JSON found in the string.")
        return None

def extract_json_from_string(string):
    # Define una expresión regular para encontrar el JSON dentro de la cadena
    json_pattern = re.compile(r'\{.*?\}', re.DOTALL)
    
    # Busca el JSON en la cadena
    match = json_pattern.search(string)
    
    if match:
        json_str = match.group(0)
        try:
            # Intenta convertir la cadena JSON a un objeto Python
            json_obj = json.loads(json_str)
            return json_obj
        except json.JSONDecodeError:
            raise ValueError("La cadena contiene un JSON no válido")
    else:
        raise ValueError("No se encontró un JSON en la cadena proporcionada")

# %%
# Path
directory_path = '/home/ec2-user/SageMaker/genebanks/data/2_images/Germplasm collection-Colombia-1990'
# Crear un DataFrame vacío
df = pd.DataFrame()

# %%
# Recorrer todas las imágenes en el directorio
for filename in os.listdir(directory_path):
    if filename.endswith(".png") or filename.endswith(".jpg") or filename.endswith(".jpeg"):
        image_path = os.path.join(directory_path, filename)

        # Codificar la imagen
        base64_image = encode_image(image_path)

        headers = {
            "Content-Type": "application/json",
            "Authorization": f"Bearer {api_key}"
        }

        payload = {
            "model": "gpt-4o",
            "messages": [
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": f"{prompt}"
                        },
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }
                    ]
                }
            ],
            "max_tokens": 1200
        }

        response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
        res = response.json()

        try:
            extracted_json = extract_json_from_string(res['choices'][0]['message']['content'])
            if extracted_json:
                # Agregar el JSON extraído al DataFrame
                df = pd.concat([df, pd.DataFrame([extracted_json])], ignore_index=True)
        except ValueError as e:
            print(e)

# Mostrar el DataFrame resultante
print(df)
# Out:
# No se encontró un JSON en la cadena proporcionada
# No se encontró un JSON en la cadena proporcionada
# La cadena contiene un JSON no válido
# No se encontró un JSON en la cadena proporcionada
# No se encontró un JSON en la cadena proporcionada
# La cadena contiene un JSON no válido
# La cadena contiene un JSON no válido
# No se encontró un JSON en la cadena proporcionada
# No se encontró un JSON en la cadena proporcionada
# La cadena contiene un JSON no válido
# La cadena contiene un JSON no válido
# La cadena contiene un JSON no válido
#                                            colectores  numero_accesión  \
# 0                DEBOUCK DG LOPEZ L ANGULO N & TORO O           2956.0
# 1                DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 2                                   Schmitz & Debouck           2912.0
# 3                                                 NaN              NaN
# 4                                          DEBOUCK DG           2948.0
# 5                                                               2935.0
# 6                                                 NaN           2983.0
# 7                DEBOUCK DG LOPEZ L ANGULO N & TORO O           2901.0
# 8                                       Gabriel Lopez              NaN
# 9                DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 10               DEBOUCK DG LOPEZ L ANGULO N & TORO O           2942.0
# 11               DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 12                                               None           2912.0
# 13  D.G. Debouck, L. Lopez J., N.F. Angulo & O. To...           2946.0
# 14               DEBOUCK DG LOPEZ L ANGULO N & TORO O           2928.0
# 15                                         DEBOUCK DG              NaN
# 16               DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
#
#         pais  departamento    municipio               especie  \
# 0        CLB        TOLIMA    CHAPARRAL            P.vulgaris
# 1        CLB         HUILA  SANTA MARIA            P. lunatus
# 2        COL         HUILA     Pitalito  Phaseolus polyanthus
# 3        NaN           NaN          NaN                   NaN
# 4        COL        Tolima         None       Cyphomandra sp.
# 5
# 6        PER           NaN          NaN    Phaseolus vulgaris
# 7        CLB         CAUCA         INZA            P.vulgaris
# 8   Colombia         Huila         Inza                   NaN
# 9        CLB  CUNDINAMARCA         TENA           P. vulgaris
# 10       CLB        TOLIMA    RIOBLANCO           P. vulgaris
# 11       CLB         HUILA     PITALITO            P.vulgaris
# 12       CLB         HUILA         None         P. polyanthus
# 13  COLOMBIA        TOLIMA    Chaparral    Viagara lasiacarpa
# 14       CLB         HUILA  SANTA MARIA             P.lunatus
# 15       CLB         HUILA  SANTA MARIA             P.lunatus
# 16       CLB        TOLIMA    CHAPARRAL            P.vulgaris
#
#              nombre_local                                              lugar  \
# 0              revolutora                        17 Km NE Chaparral, Risalda
# 1                     NaN             7 Km W Puerto El Socorro, Las Delicias
# 2                     NaN                         Monterincito (hacía Mocoa)
# 3        sardinato (grfs)                                                NaN
# 4                    None  serranía de Calarma, Tolima, a las orillas del...
# 5                     NaN                               sectores de Gaitania
# 6      frijol gargaparato                        Rosario, Tena, Cundinamarca
# 7                   comun                                        2 Km E Inza
# 8                     NaN  San Francisco-El Patio-Segovia-Guadualejo-Paez...
# 9                       x                            3 Km E Tena, El Rosario
# 10       cejudo, cejudito               10 Km S Rioblanco, Bocas de Amaníciu
# 11  frijol de tierra fría                   23 Km SW Pitalito, Vitila Fatima
# 12                  cacha  en el sur del Huila (Cordillera Picos de la Fr...
# 13                    NaN                                17 Km S San Antonio
# 14                potager             7 Km W Puerto El Socorro, Las Delicias
# 15                    NaN             7 Km W Puerto El Socorro, Las Delicias
# 16              vagabundo                       19 Km NE Chaparral, Ríoclaro
#
#    altitud longitud latitud    estatus      fuente       fecha  \
# 0     1700   75.25W  03.45N       cult   cham cult  04/09/1990
# 1     1030   75.34W  02.57N        NaN         NaN         NaN
# 2     None     None    None        NaN         NaN         NaN
# 3      NaN      NaN     NaN        NaN         NaN         NaN
# 4     None     None    None  colectado        None        None
# 5                                  NaN         NaN         NaN
# 6      200    -74.4    -4.2        NaN         NaN         NaN
# 7     1660   76.02W  02.33N       cult     potager  23/08/1990
# 8                                  NaN         NaN         NaN
# 9     1540   74.22W  04.38N       cult  champ cult  06/09/1990
# 10     760   75.40W  03.30N       cult  champ cult  02/09/1990
# 11    1520   76.12W  01.46N       cult  champ cult  27/08/1990
# 12    None     None    None        NaN         NaN         NaN
# 13    1040   75.32W  03.51N        NaN         NaN         NaN
# 14    1030   75.34W  02.57N       cult     potager  31/08/1980
# 15    1030   75.34W  02.57N        NaN         NaN         NaN
# 16    2120   75.25W  03.45N       cult  champ cult  04/09/1990
#
#    numero_accesion status_s fecha_colecta
# 0              NaN      NaN           NaN
# 1           2928.0      NaN           NaN
# 2              NaN      NaN           NaN
# 3           G02522      NaN           NaN
# 4              NaN      NaN           NaN
# 5              NaN      NaN           NaN
# 6              NaN   ceniza           NaN
# 7              NaN      NaN           NaN
# 8             2901      NaN           NaN
# 9             2984      NaN           NaN
# 10             NaN      NaN           NaN
# 11            2914      NaN           NaN
# 12             NaN      NaN           NaN
# 13             NaN      NaN    03/IX/1990
# 14             NaN      NaN           NaN
# 15            2928      NaN           NaN
# 16            2970      NaN           NaN

# %%
df
# Out:
#                                            colectores  numero_accesión  \
# 0                DEBOUCK DG LOPEZ L ANGULO N & TORO O           2956.0
# 1                DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 2                                   Schmitz & Debouck           2912.0
# 3                                                 NaN              NaN
# 4                                          DEBOUCK DG           2948.0
# 5                                                               2935.0
# 6                                                 NaN           2983.0
# 7                DEBOUCK DG LOPEZ L ANGULO N & TORO O           2901.0
# 8                                       Gabriel Lopez              NaN
# 9                DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 10               DEBOUCK DG LOPEZ L ANGULO N & TORO O           2942.0
# 11               DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
# 12                                               None           2912.0
# 13  D.G. Debouck, L. Lopez J., N.F. Angulo & O. To...           2946.0
# 14               DEBOUCK DG LOPEZ L ANGULO N & TORO O           2928.0
# 15                                         DEBOUCK DG              NaN
# 16               DEBOUCK DG LOPEZ L ANGULO N & TORO O              NaN
#
#         pais  departamento    municipio               especie  \
# 0        CLB        TOLIMA    CHAPARRAL            P.vulgaris
# 1        CLB         HUILA  SANTA MARIA            P. lunatus
# 2        COL         HUILA     Pitalito  Phaseolus polyanthus
# 3        NaN           NaN          NaN                   NaN
# 4        COL        Tolima         None       Cyphomandra sp.
# 5
# 6        PER           NaN          NaN    Phaseolus vulgaris
# 7        CLB         CAUCA         INZA            P.vulgaris
# 8   Colombia         Huila         Inza                   NaN
# 9        CLB  CUNDINAMARCA         TENA           P. vulgaris
# 10       CLB        TOLIMA    RIOBLANCO           P. vulgaris
# 11       CLB         HUILA     PITALITO            P.vulgaris
# 12       CLB         HUILA         None         P. polyanthus
# 13  COLOMBIA        TOLIMA    Chaparral    Viagara lasiacarpa
# 14       CLB         HUILA  SANTA MARIA             P.lunatus
# 15       CLB         HUILA  SANTA MARIA             P.lunatus
# 16       CLB        TOLIMA    CHAPARRAL            P.vulgaris
#
#              nombre_local                                              lugar  \
# 0              revolutora                        17 Km NE Chaparral, Risalda
# 1                     NaN             7 Km W Puerto El Socorro, Las Delicias
# 2                     NaN                         Monterincito (hacía Mocoa)
# 3        sardinato (grfs)                                                NaN
# 4                    None  serranía de Calarma, Tolima, a las orillas del...
# 5                     NaN                               sectores de Gaitania
# 6      frijol gargaparato                        Rosario, Tena, Cundinamarca
# 7                   comun                                        2 Km E Inza
# 8                     NaN  San Francisco-El Patio-Segovia-Guadualejo-Paez...
# 9                       x                            3 Km E Tena, El Rosario
# 10       cejudo, cejudito               10 Km S Rioblanco, Bocas de Amaníciu
# 11  frijol de tierra fría                   23 Km SW Pitalito, Vitila Fatima
# 12                  cacha  en el sur del Huila (Cordillera Picos de la Fr...
# 13                    NaN                                17 Km S San Antonio
# 14                potager             7 Km W Puerto El Socorro, Las Delicias
# 15                    NaN             7 Km W Puerto El Socorro, Las Delicias
# 16              vagabundo                       19 Km NE Chaparral, Ríoclaro
#
#    altitud longitud latitud    estatus      fuente       fecha  \
# 0     1700   75.25W  03.45N       cult   cham cult  04/09/1990
# 1     1030   75.34W  02.57N        NaN         NaN         NaN
# 2     None     None    None        NaN         NaN         NaN
# 3      NaN      NaN     NaN        NaN         NaN         NaN
# 4     None     None    None  colectado        None        None
# 5                                  NaN         NaN         NaN
# 6      200    -74.4    -4.2        NaN         NaN         NaN
# 7     1660   76.02W  02.33N       cult     potager  23/08/1990
# 8                                  NaN         NaN         NaN
# 9     1540   74.22W  04.38N       cult  champ cult  06/09/1990
# 10     760   75.40W  03.30N       cult  champ cult  02/09/1990
# 11    1520   76.12W  01.46N       cult  champ cult  27/08/1990
# 12    None     None    None        NaN         NaN         NaN
# 13    1040   75.32W  03.51N        NaN         NaN         NaN
# 14    1030   75.34W  02.57N       cult     potager  31/08/1980
# 15    1030   75.34W  02.57N        NaN         NaN         NaN
# 16    2120   75.25W  03.45N       cult  champ cult  04/09/1990
#
#    numero_accesion status_s fecha_colecta
# 0              NaN      NaN           NaN
# 1           2928.0      NaN           NaN
# 2              NaN      NaN           NaN
# 3           G02522      NaN           NaN
# 4              NaN      NaN           NaN
# 5              NaN      NaN           NaN
# 6              NaN   ceniza           NaN
# 7              NaN      NaN           NaN
# 8             2901      NaN           NaN
# 9             2984      NaN           NaN
# 10             NaN      NaN           NaN
# 11            2914      NaN           NaN
# 12             NaN      NaN           NaN
# 13             NaN      NaN    03/IX/1990
# 14             NaN      NaN           NaN
# 15            2928      NaN           NaN
# 16            2970      NaN           NaN

# %%
# Getting the base64 string
base64_image = encode_image(image_path)

headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
}

payload = {
  "model": "gpt-4o",
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": f"{prompt}"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 1200
}

# %%
response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

# %%
res = response.json()

# %%
print(res)
# Out:
# {'id': 'chatcmpl-9RSwocCwk6yV52Obaj1Boa99EYjMP', 'object': 'chat.completion', 'created': 1716333158, 'model': 'gpt-4o-2024-05-13', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n[\n    {\n        "colectores": "D.G. Debouck, L. Lopez J., N.F. Angulo & O. Toro Ch.//Acaros",\n        "numero_accesión": 2946,\n        "pais": "COL",\n        "departamento": "TOLIMA",\n        "municipio": "Chaparral",\n        "especie": "Vigna lasiocarpa (Bentham) Verdcourt",\n        "lugar": "17 Km S San Antonio",\n        "altitud": 1040,\n        "longitud": "75.32W",\n        "latitud": "03.51N",\n        "fecha_recolección": "03/IX/1990",\n        "determinavit": "D.G. Debouck",\n        "fecha_determinación": "14/X/1990",\n        "observaciones": "En matorrales modificados y quemados convirtiendose en potreros. Antiguo bosque tropical subhumedo con Inga, Moraceae, Gyrneirum, Mimosaceae, Compositae, crotonea, Rhynchosia, Solenoca, arbustos de porte bajo y localizado. Suelo organico pedregoso humedo derivado de andesitas. En vainas verdes, entrando madurez. Flor: amarillo. Volubles 2 m alto."\n    },\n    {\n        "colectores": "D.G. Debouck, L. Lopez J., N.F. Angulo & O. Toro Ch.//Acaros",\n        "numero_accesión": 2947,\n        "pais": "COL",\n        "departamento": "TOLIMA",\n        "municipio": "Chaparral",\n        "especie": "Vigna candida (Vell). Maréchal, Mascherpa & Stainier",\n        "lugar": "14 Km S San Antonio",\n        "altitud": 1000,\n        "longitud": "75.32W",\n        "latitud": "03.51N",\n        "fecha_recolección": "03/IX/1990",\n        "determinavit": "D.G. Debouck",\n        "fecha_determinación": "14/X/1990",\n        "observaciones": "Restos de bosque tropical subhumedo con Sapotaceae (Sapotaceae), Araceae, Moraceae (Cecropeia), Gabiatia, Solanum, Lantana, lieve abierto. Abandonado años atrás parcialmente por deforestación vainas verdes (Flor lila azul muy clara). Voluble 1-3 m alto. Perene 2-3 años."\n    }\n]\n```'}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1099, 'completion_tokens': 576, 'total_tokens': 1675}, 'system_fingerprint': 'fp_927397958d'}

# %%
def extract_json_from_string(string):
    # Define una expresión regular para encontrar el JSON dentro de la cadena
    json_pattern = re.compile(r'\{.*?\}', re.DOTALL)
    
    # Busca el JSON en la cadena
    match = json_pattern.search(string)
    
    if match:
        json_str = match.group(0)
        try:
            # Intenta convertir la cadena JSON a un objeto Python
            json_obj = json.loads(json_str)
            return json_obj
        except json.JSONDecodeError:
            raise ValueError("La cadena contiene un JSON no válido")
    else:
        raise ValueError("No se encontró un JSON en la cadena proporcionada")

# %%
try:
    extracted_json = extract_json_from_string(res['choices'][0]['message']['content'])
    print(extracted_json)
except ValueError as e:
    print(e)
# Out:
# {'colectores': 'D.G. Debouck, L. Lopez J., N.F. Angulo & O. Toro Ch.//Acaros', 'numero_accesión': 2946, 'pais': 'COL', 'departamento': 'TOLIMA', 'municipio': 'Chaparral', 'especie': 'Vigna lasiocarpa (Bentham) Verdcourt', 'lugar': '17 Km S San Antonio', 'altitud': 1040, 'longitud': '75.32W', 'latitud': '03.51N', 'fecha_recolección': '03/IX/1990', 'determinavit': 'D.G. Debouck', 'fecha_determinación': '14/X/1990', 'observaciones': 'En matorrales modificados y quemados convirtiendose en potreros. Antiguo bosque tropical subhumedo con Inga, Moraceae, Gyrneirum, Mimosaceae, Compositae, crotonea, Rhynchosia, Solenoca, arbustos de porte bajo y localizado. Suelo organico pedregoso humedo derivado de andesitas. En vainas verdes, entrando madurez. Flor: amarillo. Volubles 2 m alto.'}

# %%
df = pd.DataFrame([extracted_json])

# %%
df.head()
# Out:
#                                           colectores  numero_accesión pais  \
# 0  D.G. Debouck, L. Lopez J., N.F. Angulo & O. To...             2946  COL
#
#   departamento  municipio                               especie  \
# 0       TOLIMA  Chaparral  Vigna lasiocarpa (Bentham) Verdcourt
#
#                  lugar  altitud longitud latitud fecha_recolección  \
# 0  17 Km S San Antonio     1040   75.32W  03.51N        03/IX/1990
#
#    determinavit fecha_determinación  \
# 0  D.G. Debouck           14/X/1990
#
#                                        observaciones
# 0  En matorrales modificados y quemados convirtie...
